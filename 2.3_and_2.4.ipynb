# %%
import pandas as pd
from sklearn import tree
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\fores\\Downloads\\train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
from IPython.display import SVG
from IPython.display import display

from IPython.display import HTML
style = "<style>svg{width: 70% !important; height: 60% !important;} </style>"
HTML(style)
# Out:
# <style>svg{width: 70% !important; height: 60% !important;} </style>

# %%
X = pd.get_dummies(X)

# %%
X
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0         3  22.0      1      0   7.2500           0         1           0
# 1         1  38.0      1      0  71.2833           1         0           1
# 2         3  26.0      0      0   7.9250           1         0           0
# 3         1  35.0      1      0  53.1000           1         0           0
# 4         3  35.0      0      0   8.0500           0         1           0
# ..      ...   ...    ...    ...      ...         ...       ...         ...
# 886       2  27.0      0      0  13.0000           0         1           0
# 887       1  19.0      0      0  30.0000           1         0           0
# 888       3  28.0      1      2  23.4500           1         0           0
# 889       1  26.0      0      0  30.0000           0         1           1
# 890       3  32.0      0      0   7.7500           0         1           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 10 columns]

# %%
np.random.seed(0)

# %%
X = X.fillna({'Age' : X.Age.median()})

# %%
X.isnull().sum()
# Out:
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_female    0
# Sex_male      0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
X = df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin', 'Survived'], axis = 1)

# %%
y = df.Survived

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy')

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
plt.figure(figsize=(100, 25))
tree.plot_tree(clf, fontsize=10, feature_names=list(X), filled=True)
# Out:
# [Text(2386.952427455357, 1325.025, 'Sex_male <= 0.5\nentropy = 0.961\nsamples = 891\nvalue = [549, 342]'),
#  Text(863.1562499999999, 1257.075, 'Pclass <= 2.5\nentropy = 0.824\nsamples = 314\nvalue = [81, 233]'),
#  Text(338.7857142857143, 1189.125, 'Fare <= 28.856\nentropy = 0.299\nsamples = 170\nvalue = [9, 161]'),
#  Text(259.07142857142856, 1121.175, 'Fare <= 28.231\nentropy = 0.469\nsamples = 70\nvalue = [7, 63]'),
#  Text(219.2142857142857, 1053.225, 'Age <= 23.5\nentropy = 0.426\nsamples = 69\nvalue = [6, 63]'),
#  Text(179.35714285714283, 985.275, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(259.07142857142856, 985.275, 'Age <= 27.5\nentropy = 0.503\nsamples = 54\nvalue = [6, 48]'),
#  Text(159.42857142857142, 917.325, 'Age <= 25.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(79.71428571428571, 849.375, 'Fare <= 13.75\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(39.857142857142854, 781.425, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(119.57142857142856, 781.425, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(239.1428571428571, 849.375, 'Fare <= 17.429\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(199.28571428571428, 781.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(279.0, 781.425, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(358.71428571428567, 917.325, 'Age <= 37.0\nentropy = 0.365\nsamples = 43\nvalue = [3, 40]'),
#  Text(318.85714285714283, 849.375, 'entropy = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(398.57142857142856, 849.375, 'Age <= 39.0\nentropy = 0.629\nsamples = 19\nvalue = [3, 16]'),
#  Text(358.71428571428567, 781.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(438.4285714285714, 781.425, 'Age <= 56.0\nentropy = 0.503\nsamples = 18\nvalue = [2, 16]'),
#  Text(358.71428571428567, 713.475, 'SibSp <= 0.5\nentropy = 0.337\nsamples = 16\nvalue = [1, 15]'),
#  Text(318.85714285714283, 645.525, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(398.57142857142856, 645.525, 'Age <= 44.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(358.71428571428567, 577.5749999999999, 'Age <= 43.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(318.85714285714283, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(398.57142857142856, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(438.4285714285714, 577.5749999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(518.1428571428571, 713.475, 'Fare <= 18.525\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(478.2857142857142, 645.525, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(558.0, 645.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(298.9285714285714, 1053.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(418.49999999999994, 1121.175, 'Age <= 2.5\nentropy = 0.141\nsamples = 100\nvalue = [2, 98]'),
#  Text(378.6428571428571, 1053.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(458.35714285714283, 1053.225, 'Parch <= 1.5\nentropy = 0.081\nsamples = 99\nvalue = [1, 98]'),
#  Text(418.49999999999994, 985.275, 'entropy = 0.0\nsamples = 84\nvalue = [0, 84]'),
#  Text(498.21428571428567, 985.275, 'Age <= 24.5\nentropy = 0.353\nsamples = 15\nvalue = [1, 14]'),
#  Text(458.35714285714283, 917.325, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(538.0714285714286, 917.325, 'Age <= 28.0\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(498.21428571428567, 849.375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(577.9285714285713, 849.375, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1387.5267857142856, 1189.125, 'Fare <= 23.35\nentropy = 1.0\nsamples = 144\nvalue = [72, 72]'),
#  Text(1240.5535714285713, 1121.175, 'Age <= 36.5\nentropy = 0.977\nsamples = 117\nvalue = [48, 69]'),
#  Text(1066.1785714285713, 1053.225, 'Embarked_S <= 0.5\nentropy = 0.959\nsamples = 110\nvalue = [42, 68]'),
#  Text(836.9999999999999, 985.275, 'Fare <= 15.621\nentropy = 0.86\nsamples = 53\nvalue = [15, 38]'),
#  Text(797.1428571428571, 917.325, 'Fare <= 13.935\nentropy = 0.918\nsamples = 45\nvalue = [15, 30]'),
#  Text(657.6428571428571, 849.375, 'Age <= 17.0\nentropy = 0.758\nsamples = 32\nvalue = [7, 25]'),
#  Text(617.7857142857142, 781.425, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(697.5, 781.425, 'Fare <= 6.987\nentropy = 0.855\nsamples = 25\nvalue = [7, 18]'),
#  Text(657.6428571428571, 713.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(737.3571428571428, 713.475, 'Parch <= 1.0\nentropy = 0.811\nsamples = 24\nvalue = [6, 18]'),
#  Text(697.5, 645.525, 'Age <= 29.25\nentropy = 0.755\nsamples = 23\nvalue = [5, 18]'),
#  Text(657.6428571428571, 577.5749999999999, 'Fare <= 8.008\nentropy = 0.684\nsamples = 22\nvalue = [4, 18]'),
#  Text(617.7857142857142, 509.625, 'Fare <= 7.769\nentropy = 0.592\nsamples = 21\nvalue = [3, 18]'),
#  Text(577.9285714285713, 441.67499999999995, 'Age <= 21.5\nentropy = 0.722\nsamples = 15\nvalue = [3, 12]'),
#  Text(538.0714285714286, 373.7249999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(617.7857142857142, 373.7249999999999, 'Fare <= 7.681\nentropy = 0.592\nsamples = 14\nvalue = [2, 12]'),
#  Text(538.0714285714286, 305.77499999999986, 'Embarked_Q <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(498.21428571428567, 237.82500000000005, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(577.9285714285713, 237.82500000000005, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(697.5, 305.77499999999986, 'Fare <= 7.744\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]'),
#  Text(657.6428571428571, 237.82500000000005, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(737.3571428571428, 237.82500000000005, 'Age <= 25.0\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(697.5, 169.875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(777.2142857142857, 169.875, 'entropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(657.6428571428571, 441.67499999999995, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(697.5, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(737.3571428571428, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(777.2142857142857, 645.525, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(936.6428571428571, 849.375, 'Embarked_C <= 0.5\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(856.9285714285713, 781.425, 'Age <= 30.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(817.0714285714286, 713.475, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(896.7857142857142, 713.475, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1016.3571428571428, 781.425, 'Age <= 28.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(976.4999999999999, 713.475, 'Age <= 16.0\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(936.6428571428571, 645.525, 'Age <= 14.75\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(896.7857142857142, 577.5749999999999, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(976.4999999999999, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1016.3571428571428, 645.525, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(1056.2142857142856, 713.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(876.8571428571428, 917.325, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(1295.3571428571427, 985.275, 'Age <= 32.0\nentropy = 0.998\nsamples = 57\nvalue = [27, 30]'),
#  Text(1255.5, 917.325, 'Fare <= 7.763\nentropy = 1.0\nsamples = 54\nvalue = [27, 27]'),
#  Text(1135.9285714285713, 849.375, 'Age <= 25.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(1096.0714285714284, 781.425, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(1175.7857142857142, 781.425, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1375.0714285714284, 849.375, 'Fare <= 10.825\nentropy = 0.995\nsamples = 48\nvalue = [26, 22]'),
#  Text(1255.5, 781.425, 'Fare <= 10.152\nentropy = 0.918\nsamples = 27\nvalue = [18, 9]'),
#  Text(1215.642857142857, 713.475, 'Parch <= 0.5\nentropy = 0.954\nsamples = 24\nvalue = [15, 9]'),
#  Text(1175.7857142857142, 645.525, 'Fare <= 9.84\nentropy = 0.902\nsamples = 22\nvalue = [15, 7]'),
#  Text(1135.9285714285713, 577.5749999999999, 'Fare <= 8.767\nentropy = 0.863\nsamples = 21\nvalue = [15, 6]'),
#  Text(1096.0714285714284, 509.625, 'Fare <= 8.673\nentropy = 0.937\nsamples = 17\nvalue = [11, 6]'),
#  Text(1056.2142857142856, 441.67499999999995, 'Age <= 27.5\nentropy = 0.896\nsamples = 16\nvalue = [11, 5]'),
#  Text(1016.3571428571428, 373.7249999999999, 'Age <= 25.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(976.4999999999999, 305.77499999999986, 'Age <= 22.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(936.6428571428571, 237.82500000000005, 'Age <= 18.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(896.7857142857142, 169.875, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(976.4999999999999, 169.875, 'Fare <= 8.258\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(936.6428571428571, 101.92499999999995, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1016.3571428571428, 101.92499999999995, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1016.3571428571428, 237.82500000000005, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1056.2142857142856, 305.77499999999986, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1096.0714285714284, 373.7249999999999, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(1135.9285714285713, 441.67499999999995, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1175.7857142857142, 509.625, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(1215.642857142857, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1255.5, 645.525, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1295.3571428571427, 713.475, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1494.642857142857, 781.425, 'Fare <= 17.25\nentropy = 0.959\nsamples = 21\nvalue = [8, 13]'),
#  Text(1375.0714285714284, 713.475, 'SibSp <= 0.5\nentropy = 0.619\nsamples = 13\nvalue = [2, 11]'),
#  Text(1335.2142857142856, 645.525, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(1414.9285714285713, 645.525, 'Age <= 25.0\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(1375.0714285714284, 577.5749999999999, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1454.7857142857142, 577.5749999999999, 'Parch <= 0.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(1414.9285714285713, 509.625, 'Age <= 27.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(1375.0714285714284, 441.67499999999995, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1454.7857142857142, 441.67499999999995, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1494.642857142857, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1614.2142857142856, 713.475, 'Fare <= 21.55\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(1574.3571428571427, 645.525, 'Age <= 30.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(1534.4999999999998, 577.5749999999999, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(1614.2142857142856, 577.5749999999999, 'Parch <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1574.3571428571427, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1654.0714285714284, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1654.0714285714284, 645.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1335.2142857142856, 917.325, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1414.9285714285713, 1053.225, 'Age <= 55.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(1375.0714285714284, 985.275, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1454.7857142857142, 985.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1534.4999999999998, 1121.175, 'Parch <= 0.5\nentropy = 0.503\nsamples = 27\nvalue = [24, 3]'),
#  Text(1494.642857142857, 1053.225, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1574.3571428571427, 1053.225, 'Fare <= 31.331\nentropy = 0.391\nsamples = 26\nvalue = [24, 2]'),
#  Text(1534.4999999999998, 985.275, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(1614.2142857142856, 985.275, 'Fare <= 32.881\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(1574.3571428571427, 917.325, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1654.0714285714284, 917.325, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(3910.7486049107138, 1257.075, 'Fare <= 26.269\nentropy = 0.699\nsamples = 577\nvalue = [468, 109]'),
#  Text(2782.0597098214284, 1189.125, 'Age <= 13.5\nentropy = 0.558\nsamples = 415\nvalue = [361, 54]'),
#  Text(2062.6071428571427, 1121.175, 'SibSp <= 2.0\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(2022.7499999999998, 1053.225, 'Age <= 10.0\nentropy = 0.371\nsamples = 14\nvalue = [1, 13]'),
#  Text(1982.8928571428569, 985.275, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(2062.6071428571427, 985.275, 'SibSp <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2022.7499999999998, 917.325, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2102.464285714286, 917.325, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2102.464285714286, 1053.225, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3501.512276785714, 1121.175, 'Embarked_C <= 0.5\nentropy = 0.477\nsamples = 400\nvalue = [359, 41]'),
#  Text(2997.381696428571, 1053.225, 'Fare <= 13.25\nentropy = 0.437\nsamples = 355\nvalue = [323, 32]'),
#  Text(2537.15625, 985.275, 'Fare <= 7.91\nentropy = 0.479\nsamples = 291\nvalue = [261, 30]'),
#  Text(2182.178571428571, 917.325, 'Fare <= 7.865\nentropy = 0.353\nsamples = 150\nvalue = [140, 10]'),
#  Text(2142.3214285714284, 849.375, 'Age <= 32.5\nentropy = 0.424\nsamples = 116\nvalue = [106, 10]'),
#  Text(2102.464285714286, 781.425, 'Age <= 20.75\nentropy = 0.507\nsamples = 89\nvalue = [79, 10]'),
#  Text(2062.6071428571427, 713.475, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(2142.3214285714284, 713.475, 'Fare <= 7.763\nentropy = 0.576\nsamples = 73\nvalue = [63, 10]'),
#  Text(1873.2857142857142, 645.525, 'Age <= 27.5\nentropy = 0.451\nsamples = 53\nvalue = [48, 5]'),
#  Text(1773.642857142857, 577.5749999999999, 'Fare <= 7.013\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]'),
#  Text(1733.7857142857142, 509.625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1813.4999999999998, 509.625, 'Fare <= 7.196\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(1773.642857142857, 441.67499999999995, 'Fare <= 7.133\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(1733.7857142857142, 373.7249999999999, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(1813.4999999999998, 373.7249999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1853.3571428571427, 441.67499999999995, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(1972.9285714285713, 577.5749999999999, 'Fare <= 7.744\nentropy = 0.31\nsamples = 36\nvalue = [34, 2]'),
#  Text(1933.0714285714284, 509.625, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(2012.7857142857142, 509.625, 'Age <= 28.5\nentropy = 0.592\nsamples = 14\nvalue = [12, 2]'),
#  Text(1933.0714285714284, 441.67499999999995, 'SibSp <= 0.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(1893.2142857142856, 373.7249999999999, 'entropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(1972.9285714285713, 373.7249999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2092.5, 441.67499999999995, 'Age <= 30.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(2052.642857142857, 373.7249999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2132.3571428571427, 373.7249999999999, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2411.3571428571427, 645.525, 'Age <= 31.5\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(2371.5, 577.5749999999999, 'Fare <= 7.798\nentropy = 0.742\nsamples = 19\nvalue = [15, 4]'),
#  Text(2331.642857142857, 509.625, 'Age <= 28.5\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(2291.785714285714, 441.67499999999995, 'Age <= 26.5\nentropy = 0.946\nsamples = 11\nvalue = [7, 4]'),
#  Text(2212.0714285714284, 373.7249999999999, 'Age <= 25.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(2172.2142857142853, 305.77499999999986, 'Age <= 21.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(2092.5, 237.82500000000005, 'Fare <= 7.785\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2052.642857142857, 169.875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2132.3571428571427, 169.875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2251.928571428571, 237.82500000000005, 'Fare <= 7.785\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(2212.0714285714284, 169.875, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2291.785714285714, 169.875, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2251.928571428571, 305.77499999999986, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2371.5, 373.7249999999999, 'Age <= 27.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(2331.642857142857, 305.77499999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2411.3571428571427, 305.77499999999986, 'Fare <= 7.785\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(2371.5, 237.82500000000005, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2451.2142857142853, 237.82500000000005, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2371.5, 441.67499999999995, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2411.3571428571427, 509.625, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(2451.2142857142853, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2182.178571428571, 781.425, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(2222.035714285714, 849.375, 'entropy = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(2892.1339285714284, 917.325, 'Fare <= 7.988\nentropy = 0.589\nsamples = 141\nvalue = [121, 20]'),
#  Text(2690.3571428571427, 849.375, 'SibSp <= 1.5\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(2650.5, 781.425, 'Age <= 41.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(2610.642857142857, 713.475, 'SibSp <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(2570.785714285714, 645.525, 'Age <= 26.0\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(2530.928571428571, 577.5749999999999, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2610.642857142857, 577.5749999999999, 'Age <= 31.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(2570.785714285714, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2650.5, 509.625, 'Age <= 35.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(2610.642857142857, 441.67499999999995, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(2690.3571428571427, 441.67499999999995, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2650.5, 645.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2690.3571428571427, 713.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2730.2142857142853, 781.425, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3093.910714285714, 849.375, 'Age <= 19.5\nentropy = 0.521\nsamples = 128\nvalue = [113, 15]'),
#  Text(2849.785714285714, 781.425, 'Fare <= 8.104\nentropy = 0.722\nsamples = 20\nvalue = [16, 4]'),
#  Text(2770.0714285714284, 713.475, 'Age <= 17.0\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(2730.2142857142853, 645.525, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2809.928571428571, 645.525, 'Age <= 18.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(2770.0714285714284, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2849.785714285714, 577.5749999999999, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2929.5, 713.475, 'Age <= 18.5\nentropy = 0.353\nsamples = 15\nvalue = [14, 1]'),
#  Text(2889.642857142857, 645.525, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(2969.3571428571427, 645.525, 'Fare <= 10.335\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(2929.5, 577.5749999999999, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3009.2142857142853, 577.5749999999999, 'Fare <= 11.75\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(2969.3571428571427, 509.625, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3049.0714285714284, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3338.035714285714, 781.425, 'Age <= 26.5\nentropy = 0.475\nsamples = 108\nvalue = [97, 11]'),
#  Text(3298.178571428571, 713.475, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(3377.892857142857, 713.475, 'Fare <= 8.081\nentropy = 0.592\nsamples = 77\nvalue = [66, 11]'),
#  Text(3128.785714285714, 645.525, 'Age <= 31.25\nentropy = 0.371\nsamples = 28\nvalue = [26, 2]'),
#  Text(3088.928571428571, 577.5749999999999, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(3168.642857142857, 577.5749999999999, 'Age <= 33.0\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(3128.785714285714, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3208.4999999999995, 509.625, 'Age <= 44.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(3168.642857142857, 441.67499999999995, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(3248.3571428571427, 441.67499999999995, 'Age <= 47.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(3208.4999999999995, 373.7249999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3288.2142857142853, 373.7249999999999, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3626.9999999999995, 645.525, 'Fare <= 8.238\nentropy = 0.688\nsamples = 49\nvalue = [40, 9]'),
#  Text(3587.142857142857, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3666.8571428571427, 577.5749999999999, 'Fare <= 8.658\nentropy = 0.65\nsamples = 48\nvalue = [40, 8]'),
#  Text(3626.9999999999995, 509.625, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(3706.7142857142853, 509.625, 'Age <= 31.5\nentropy = 0.684\nsamples = 44\nvalue = [36, 8]'),
#  Text(3487.4999999999995, 441.67499999999995, 'Fare <= 10.0\nentropy = 0.811\nsamples = 20\nvalue = [15, 5]'),
#  Text(3367.928571428571, 373.7249999999999, 'Age <= 27.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(3328.0714285714284, 305.77499999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3407.785714285714, 305.77499999999986, 'Age <= 28.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]'),
#  Text(3367.928571428571, 237.82500000000005, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(3447.642857142857, 237.82500000000005, 'Fare <= 9.492\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(3407.785714285714, 169.875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3487.4999999999995, 169.875, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(3607.0714285714284, 373.7249999999999, 'Fare <= 11.75\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(3567.2142857142853, 305.77499999999986, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(3646.928571428571, 305.77499999999986, 'Age <= 30.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(3607.0714285714284, 237.82500000000005, 'Age <= 29.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(3567.2142857142853, 169.875, 'Age <= 27.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(3527.3571428571427, 101.92499999999995, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3607.0714285714284, 101.92499999999995, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3646.928571428571, 169.875, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3686.785714285714, 237.82500000000005, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3925.928571428571, 441.67499999999995, 'Pclass <= 2.5\nentropy = 0.544\nsamples = 24\nvalue = [21, 3]'),
#  Text(3886.0714285714284, 373.7249999999999, 'Age <= 59.5\nentropy = 0.61\nsamples = 20\nvalue = [17, 3]'),
#  Text(3806.3571428571427, 305.77499999999986, 'Fare <= 12.762\nentropy = 0.523\nsamples = 17\nvalue = [15, 2]'),
#  Text(3766.4999999999995, 237.82500000000005, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(3846.2142857142853, 237.82500000000005, 'Age <= 45.0\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(3806.3571428571427, 169.875, 'Age <= 40.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(3766.4999999999995, 101.92499999999995, 'Age <= 35.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(3726.642857142857, 33.97499999999991, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(3806.3571428571427, 33.97499999999991, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3846.2142857142853, 101.92499999999995, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3886.0714285714284, 169.875, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3965.7857142857138, 305.77499999999986, 'Age <= 64.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(3925.928571428571, 237.82500000000005, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4005.642857142857, 237.82500000000005, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3965.7857142857138, 373.7249999999999, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(3457.6071428571427, 985.275, 'Fare <= 22.887\nentropy = 0.201\nsamples = 64\nvalue = [62, 2]'),
#  Text(3417.7499999999995, 917.325, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0]'),
#  Text(3497.4642857142853, 917.325, 'Fare <= 23.35\nentropy = 0.381\nsamples = 27\nvalue = [25, 2]'),
#  Text(3457.6071428571427, 849.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3537.3214285714284, 849.375, 'Age <= 33.0\nentropy = 0.235\nsamples = 26\nvalue = [25, 1]'),
#  Text(3497.4642857142853, 781.425, 'Age <= 31.5\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(3457.6071428571427, 713.475, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(3537.3214285714284, 713.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3577.178571428571, 781.425, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(4005.642857142857, 1053.225, 'Fare <= 15.148\nentropy = 0.722\nsamples = 45\nvalue = [36, 9]'),
#  Text(3925.928571428571, 985.275, 'Age <= 29.5\nentropy = 0.552\nsamples = 39\nvalue = [34, 5]'),
#  Text(3886.0714285714284, 917.325, 'Age <= 28.75\nentropy = 0.65\nsamples = 30\nvalue = [25, 5]'),
#  Text(3846.2142857142853, 849.375, 'Age <= 22.5\nentropy = 0.579\nsamples = 29\nvalue = [25, 4]'),
#  Text(3706.7142857142853, 781.425, 'Age <= 18.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(3666.8571428571427, 713.475, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3746.5714285714284, 713.475, 'Fare <= 5.619\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(3706.7142857142853, 645.525, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3786.428571428571, 645.525, 'Fare <= 7.227\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(3746.5714285714284, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3826.2857142857138, 577.5749999999999, 'Age <= 21.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3786.428571428571, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3866.142857142857, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3985.7142857142853, 781.425, 'Pclass <= 2.5\nentropy = 0.426\nsamples = 23\nvalue = [21, 2]'),
#  Text(3905.9999999999995, 713.475, 'Fare <= 14.454\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(3866.142857142857, 645.525, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3945.8571428571427, 645.525, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(4065.428571428571, 713.475, 'Fare <= 7.227\nentropy = 0.286\nsamples = 20\nvalue = [19, 1]'),
#  Text(4025.5714285714284, 645.525, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(4105.285714285714, 645.525, 'Fare <= 7.562\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]'),
#  Text(4065.428571428571, 577.5749999999999, 'Age <= 25.75\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(4025.5714285714284, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4105.285714285714, 509.625, 'Age <= 28.25\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(4065.428571428571, 441.67499999999995, 'entropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(4145.142857142857, 441.67499999999995, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4145.142857142857, 577.5749999999999, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(3925.928571428571, 849.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3965.7857142857138, 917.325, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(4085.3571428571427, 985.275, 'Fare <= 20.233\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(4045.4999999999995, 917.325, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(4125.214285714285, 917.325, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(5039.4375, 1189.125, 'SibSp <= 2.5\nentropy = 0.924\nsamples = 162\nvalue = [107, 55]'),
#  Text(4919.866071428571, 1121.175, 'Age <= 13.5\nentropy = 0.964\nsamples = 139\nvalue = [85, 54]'),
#  Text(4880.008928571428, 1053.225, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(4959.723214285714, 1053.225, 'Fare <= 26.469\nentropy = 0.939\nsamples = 132\nvalue = [85, 47]'),
#  Text(4919.866071428571, 985.275, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(4999.580357142857, 985.275, 'Age <= 53.0\nentropy = 0.921\nsamples = 128\nvalue = [85, 43]'),
#  Text(4498.875, 917.325, 'Fare <= 26.775\nentropy = 0.956\nsamples = 106\nvalue = [66, 40]'),
#  Text(4384.285714285714, 849.375, 'Age <= 46.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(4344.428571428571, 781.425, 'Embarked_C <= 0.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(4304.571428571428, 713.475, 'Age <= 39.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(4264.714285714285, 645.525, 'Age <= 31.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(4224.857142857142, 577.5749999999999, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(4304.571428571428, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4344.428571428571, 645.525, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(4384.285714285714, 713.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4424.142857142857, 781.425, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4613.464285714285, 849.375, 'Fare <= 29.1\nentropy = 0.925\nsamples = 97\nvalue = [64, 33]'),
#  Text(4573.607142857142, 781.425, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(4653.321428571428, 781.425, 'Fare <= 30.598\nentropy = 0.954\nsamples = 88\nvalue = [55, 33]'),
#  Text(4464.0, 713.475, 'Age <= 28.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]'),
#  Text(4424.142857142857, 645.525, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(4503.857142857142, 645.525, 'Fare <= 30.285\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(4464.0, 577.5749999999999, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(4543.714285714285, 577.5749999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4842.642857142857, 713.475, 'Fare <= 52.277\nentropy = 0.918\nsamples = 78\nvalue = [52, 26]'),
#  Text(4663.285714285714, 645.525, 'Age <= 47.5\nentropy = 0.619\nsamples = 26\nvalue = [22, 4]'),
#  Text(4623.428571428571, 577.5749999999999, 'Fare <= 36.125\nentropy = 0.529\nsamples = 25\nvalue = [22, 3]'),
#  Text(4583.571428571428, 509.625, 'Fare <= 35.25\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(4503.857142857142, 441.67499999999995, 'Embarked_S <= 0.5\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(4464.0, 373.7249999999999, 'Age <= 34.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(4424.142857142857, 305.77499999999986, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4503.857142857142, 305.77499999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4543.714285714285, 373.7249999999999, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(4663.285714285714, 441.67499999999995, 'Age <= 36.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(4623.428571428571, 373.7249999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4703.142857142857, 373.7249999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4663.285714285714, 509.625, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(4703.142857142857, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5022.0, 645.525, 'Fare <= 59.087\nentropy = 0.983\nsamples = 52\nvalue = [30, 22]'),
#  Text(4822.714285714285, 577.5749999999999, 'Age <= 22.0\nentropy = 0.896\nsamples = 16\nvalue = [5, 11]'),
#  Text(4782.857142857142, 509.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4862.571428571428, 509.625, 'Age <= 49.5\nentropy = 0.837\nsamples = 15\nvalue = [4, 11]'),
#  Text(4822.714285714285, 441.67499999999995, 'Age <= 27.5\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]'),
#  Text(4782.857142857142, 373.7249999999999, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(4862.571428571428, 373.7249999999999, 'Age <= 29.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(4822.714285714285, 305.77499999999986, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(4902.428571428571, 305.77499999999986, 'Fare <= 54.798\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(4862.571428571428, 237.82500000000005, 'Fare <= 52.827\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(4822.714285714285, 169.875, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4902.428571428571, 169.875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4942.285714285714, 237.82500000000005, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(4902.428571428571, 441.67499999999995, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5221.285714285714, 577.5749999999999, 'Fare <= 379.925\nentropy = 0.888\nsamples = 36\nvalue = [25, 11]'),
#  Text(5181.428571428571, 509.625, 'Fare <= 134.642\nentropy = 0.834\nsamples = 34\nvalue = [25, 9]'),
#  Text(5141.571428571428, 441.67499999999995, 'Fare <= 86.29\nentropy = 0.906\nsamples = 28\nvalue = [19, 9]'),
#  Text(5022.0, 373.7249999999999, 'Embarked_C <= 0.5\nentropy = 0.65\nsamples = 18\nvalue = [15, 3]'),
#  Text(4982.142857142857, 305.77499999999986, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(5061.857142857142, 305.77499999999986, 'Fare <= 77.965\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(5022.0, 237.82500000000005, 'Age <= 49.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(4982.142857142857, 169.875, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(5061.857142857142, 169.875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5101.714285714285, 237.82500000000005, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(5261.142857142857, 373.7249999999999, 'Embarked_S <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(5221.285714285714, 305.77499999999986, 'Parch <= 1.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(5181.428571428571, 237.82500000000005, 'Fare <= 98.752\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(5141.571428571428, 169.875, 'SibSp <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(5101.714285714285, 101.92499999999995, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(5181.428571428571, 101.92499999999995, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5221.285714285714, 169.875, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(5261.142857142857, 237.82500000000005, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5301.0, 305.77499999999986, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(5221.285714285714, 441.67499999999995, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(5261.142857142857, 509.625, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(5500.285714285714, 917.325, 'Age <= 75.5\nentropy = 0.575\nsamples = 22\nvalue = [19, 3]'),
#  Text(5460.428571428571, 849.375, 'Embarked_S <= 0.5\nentropy = 0.454\nsamples = 21\nvalue = [19, 2]'),
#  Text(5420.571428571428, 781.425, 'SibSp <= 0.5\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(5380.714285714285, 713.475, 'Age <= 57.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(5340.857142857142, 645.525, 'Fare <= 33.098\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(5301.0, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5380.714285714285, 577.5749999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5420.571428571428, 645.525, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(5460.428571428571, 713.475, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5500.285714285714, 781.425, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(5540.142857142857, 849.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5159.008928571428, 1121.175, 'Age <= 3.5\nentropy = 0.258\nsamples = 23\nvalue = [22, 1]'),
#  Text(5119.151785714285, 1053.225, 'Age <= 2.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(5079.294642857142, 985.275, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(5159.008928571428, 985.275, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5198.866071428571, 1053.225, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]')]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape
# Out:
# (596, 10)

# %%
clf.score(X,y)
# Out:
# 0.9797979797979798

# %%
clf.score(X_train, y_train)
# Out:
# 0.9798657718120806

# %%
clf.score(X_test, y_test)
# Out:
# 0.7661016949152543

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 3)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.score(X_train, y_train)
# Out:
# 0.8238255033557047

# %%
clf.score(X_test, y_test)
# Out:
# 0.8203389830508474

# %%
max_depth_values = range(1, 100)

# %%
scores_data = pd.DataFrame()

# %%
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = max_depth )
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    mean_cross_val_score = cross_val_score(clf, X_train, y_train, cv = 5).mean()
    temp_score_data = pd.DataFrame({'max_depth' : [max_depth],
                                    'train_score' : [train_score],
                                    'test_score' : [test_score],
                                    'cross_val_score' : [mean_cross_val_score]})
    scores_data = scores_data.append(temp_score_data)

# %%
scores_data.head()
# Out:
#    max_depth  train_score  test_score  cross_val_score
# 0          1     0.781879    0.796610         0.781961
# 0          2     0.805369    0.776271         0.770196
# 0          3     0.823826    0.820339         0.790322
# 0          4     0.833893    0.823729         0.788627
# 0          5     0.840604    0.810169         0.802073

# %%
scores_data_long = scores_data.melt(id_vars=['max_depth'],
                                    value_vars=['train_score', 'test_score', 'cross_val_score', 'accuracy_score'],
                                    var_name='set_type',
                                    value_name = 'score')

# %% [markdown]
# df.melt(id_vars=['A'], value_vars=['B'],
#         var_name='myVarname', value_name='myValname')

# %%
scores_data_long
# Out:
#      max_depth        set_type     score
# 0            1     train_score  0.716418
# 1            2     train_score  1.000000
# 2            3     train_score  1.000000
# 3            4     train_score  1.000000
# 4            5     train_score  1.000000
# ..         ...             ...       ...
# 391         95  accuracy_score  0.920000
# 392         96  accuracy_score  0.920000
# 393         97  accuracy_score  0.920000
# 394         98  accuracy_score  0.920000
# 395         99  accuracy_score  0.920000
#
# [396 rows x 3 columns]

# %%
sns.__version__
# Out:
# '0.10.1'

# %%
sns.lineplot(x = 'max_depth', y = 'score', hue = 'set_type', data = scores_data_long)

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)

# %%
cross_val_score(clf, X_train, y_train, cv = 5).mean()
# Out:
# 0.7886274509803922

# %%
best_clf = clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 10)

# %%
cross_val_score(best_clf, X_test, y_test, cv = 5).mean()
# Out:
# 0.7932203389830509

# %%
df = pd.read_csv('C:\\Users\\fores\\Downloads\\train_iris.csv')

# %%
df
# Out:
#     Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0          130           7.4          2.8           6.1          1.9        2
# 1            7           5.0          3.4           1.5          0.2        0
# 2           11           4.8          3.4           1.6          0.2        0
# 3          142           5.8          2.7           5.1          1.9        2
# 4          109           7.2          3.6           6.1          2.5        2
# ..         ...           ...          ...           ...          ...      ...
# 95         147           6.5          3.0           5.2          2.0        2
# 96         124           6.7          3.3           5.7          2.1        2
# 97         123           6.3          2.7           4.9          1.8        2
# 98         146           6.3          2.5           5.0          1.9        2
# 99          68           6.2          2.2           4.5          1.5        1
#
# [100 rows x 6 columns]

# %%
X = df.drop(['Unnamed: 0', 'species'], axis = 1)

# %%
y = df.species

# %%
np.random.seed(0)

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy')

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
max_depth_values = range(1, 100)

# %%
scores_data = pd.DataFrame()

# %%
for max_depth in max_depth_values:
    clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = max_depth )
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    accuracy_score = clf.score(X_testt, y_testt)
    mean_cross_val_score = cross_val_score(clf, X_train, y_train, cv = 5).mean()
    temp_score_data = pd.DataFrame({'max_depth' : [max_depth],
                                    'train_score' : [train_score],
                                    'test_score' : [test_score],
                                    'cross_val_score' : [mean_cross_val_score],
                                    'accuracy_score' : [accuracy_score]})
    scores_data = scores_data.append(temp_score_data)

# %%
scores_data
# Out:
#     max_depth  train_score  test_score  cross_val_score  accuracy_score
# 0           1     0.716418    0.666667         0.716484            0.60
# 0           2     1.000000    0.909091         1.000000            0.92
# 0           3     1.000000    0.909091         1.000000            0.92
# 0           4     1.000000    0.909091         1.000000            0.92
# 0           5     1.000000    0.909091         1.000000            0.92
# ..        ...          ...         ...              ...             ...
# 0          95     1.000000    0.909091         1.000000            0.92
# 0          96     1.000000    0.909091         1.000000            0.92
# 0          97     1.000000    0.909091         1.000000            0.92
# 0          98     1.000000    0.909091         1.000000            0.92
# 0          99     1.000000    0.909091         1.000000            0.92
#
# [99 rows x 5 columns]

# %%
test_iris = pd.read_csv('C:\\Users\\fores\\Downloads\\test_iris.csv')

# %%
test_iris.head()
# Out:
#    Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0         114           5.8          2.8           5.1          2.4        2
# 1          70           5.9          3.2           4.8          1.8        1
# 2         138           6.0          3.0           4.8          1.8        2
# 3          59           5.2          2.7           3.9          1.4        1
# 4          44           5.1          3.8           1.9          0.4        0

# %%
X_testt = test_iris.drop(['Unnamed: 0', 'species'], axis = 1)

# %%
y_testt = test_iris.species

# %%
clf.score(X_testt, y_testt )
# Out:
# 0.92

# %%
sns.lineplot(x = 'max_depth', y = 'score', hue = 'set_type', data = scores_data_long[[]])

# %%
df = pd.read_csv('C:\\Users\\fores\\Downloads\\dogs_n_cats.csv')

# %%
df
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0       15    18.0         1        1                   0  собачка
# 1       20    24.0         1        0                   0  собачка
# 2       34    40.8         1        1                   0  собачка
# 3       26    31.2         1        1                   0  собачка
# 4       16    19.2         1        1                   0  собачка
# ..     ...     ...       ...      ...                 ...      ...
# 995      8     3.2         1        0                   1    котик
# 996      7     2.8         1        0                   1    котик
# 997      6     2.4         1        0                   1    котик
# 998      7     2.8         1        0                   1    котик
# 999     11     4.4         1        0                   1    котик
#
# [1000 rows x 6 columns]

# %%
X = aa.drop(['Вид'], axis = 1)

# %%
aa = pd.get_dummies(df).drop('Вид_котик', axis = 1).rename(columns={'Вид_собачка' : 'Вид'})

# %%
y = aa[['Вид']]

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 3)

# %%
ass = clf.fit(X, y)

# %%
clf.score(X,y)
# Out:
# 1.0

# %%
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
list(clf.predict(X)).count(0)
# Out:
# 500

# %%
aa
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям  Вид
# 0       15    18.0         1        1                   0    1
# 1       20    24.0         1        0                   0    1
# 2       34    40.8         1        1                   0    1
# 3       26    31.2         1        1                   0    1
# 4       16    19.2         1        1                   0    1
# ..     ...     ...       ...      ...                 ...  ...
# 995      8     3.2         1        0                   1    0
# 996      7     2.8         1        0                   1    0
# 997      6     2.4         1        0                   1    0
# 998      7     2.8         1        0                   1    0
# 999     11     4.4         1        0                   1    0
#
# [1000 rows x 6 columns]

# %%
X
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям
# 0       15    18.0         1        1                   0
# 1       20    24.0         1        0                   0
# 2       34    40.8         1        1                   0
# 3       26    31.2         1        1                   0
# 4       16    19.2         1        1                   0
# ..     ...     ...       ...      ...                 ...
# 995      8     3.2         1        0                   1
# 996      7     2.8         1        0                   1
# 997      6     2.4         1        0                   1
# 998      7     2.8         1        0                   1
# 999     11     4.4         1        0                   1
#
# [1000 rows x 5 columns]

# %%
qq = pd.read_json('C:\\Users\\fores\\Downloads\\dataset_209691_15.txt')

# %%
qq
# Out:
#     Длина  Высота  Шерстист  Гавкает  Лазает по деревьям
# 0      33    39.6         1        1                   0
# 1      34    40.8         1        1                   0
# 2      18    21.6         1        1                   0
# 3      23    27.6         1        1                   0
# 4      31    37.2         1        1                   0
# ..    ...     ...       ...      ...                 ...
# 95      7     2.8         1        0                   1
# 96     14     5.6         1        0                   1
# 97      6     2.4         1        0                   1
# 98     14     5.6         1        0                   1
# 99     12     4.8         1        0                   1
#
# [100 rows x 5 columns]

# %%
clf.predict(qq).sum()
# Out:
# 42
