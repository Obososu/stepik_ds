# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\fores\\Downloads\\income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
sns.lineplot(data=df)

# %%
df.income.plot()

# %%
df['income'].plot()

# %%
plt.plot(df.index, df.income)

# %%
df.plot()

# %%
df.plot(kind='line')

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
sns.__version__
# Out:
# '0.10.1'

# %%
az = pd.read_csv('C:\\Users\\fores\\Downloads\\dataset_209770_6.txt', sep = ' ')

# %%
az
# Out:
#               x            y
# 0    805.810145    91.099769
# 1   1296.295530  1211.160067
# 2   1204.929458   684.091148
# 3   1500.252048   395.683404
# 4    387.644162  1286.580170
# ..          ...          ...
# 75  1304.429344  1209.601342
# 76   796.843055    81.375029
# 77   398.057989  1313.308868
# 78   401.260667  1305.206944
# 79  1002.168057   602.907201
#
# [80 rows x 2 columns]

# %%
az.skatter.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-878b40a3f6f3> in <module>
# ----> 1 az.skatter.plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'skatter'

# %%
az.plot.scatter(x = 'x', y = 'y')

# %%
sns.scatterplot(az.iloc[:, 0], az.iloc[:, 1])

# %%
df = pd.read_csv('C:\\Users\\fores\\Downloads\\genome_matrix.csv', index_col = 0)

# %%
df
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(df, cmap = "viridis")

# %%
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
df['count_roles'] = df.roles.str.split(',').str.len()

# %%
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
az = df.groupby('count_roles', as_index = False).agg({'id' : 'count'})

# %%
az.barplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-0859238b9a19> in <module>
# ----> 1 az.barplot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'barplot'

# %%
az
# Out:
#    count_roles  id
# 0            1   1
# 1            2   9
# 2            3  28
# 3            4  38
# 4            5  33
# 5            6   8

# %%
sns.barplot(x = 'count_roles', y = 'id', data = az)

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col = False)

# %%
df
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
for column in qq[qq.columns[1:]]:
    a = sns.distplot(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-6bf5b99ac18a> in <module>
#       1 for column in qq[qq.columns[1:]]:
# ----> 2     a = sns.distplot(x, a = df['sepal length'])
#       3
#
# TypeError: distplot() got multiple values for argument 'a'

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['sepal length'])
sns.distplot(df['sepal width'])

# %%
sns.distplot(df['petal length'])

# %%
sns.violinplot(y = 'petal length', data = df)

# %%
sns.violinplot(df['petal length'], orient='v');

# %%
a = sns.pairplot(data = df)

# %%
df.corr().drop(['Unnamed: 0','species'], axis = 1).drop(['Unnamed: 0','species'], axis = 0)
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000
